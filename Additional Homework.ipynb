# %%
#parent class
class Amazon:
    def __init__(self, total):
        self.total=df["Total Charged"]
    import pandas as pd
    def month(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        month=df.groupby(pd.PeriodIndex(df["Order Date"],freq='M'))["Total Charged"].sum()
        print("monthly summary: ", month)
        print("median: ", df["Total Charged"].median())
    def mean(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("mean: ", df["Total Charged"].mean())
    def median(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("median: ", df["Total Charged"].median())
    def max(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("max: ", df["Total Charged"].max())
    def min(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("min: ", df["Total Charged"].min())
    def std(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("std: ", df["Total Charged"].std())
    def sum(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        print("sum: ", df["Total Charged"].sum())
    #try except main function 
    def main():
        input_readable = False
        while True:
            try: 
                f = input("Input a file name:")
                fp = open(f, "r")
                while fp:
                    return fp
            #error statement if file cannot be found
            except FileNotFoundError:
                print("Something went wrong when opening this file. Try Again.")
            else:
                input_readable = True
        if __name__=='main':
            main()
main()
x=Amazon(total)
x.month()
x.mean()
x.median()
x.max()
x.min()
x.std()
x.sum()
# Out:
# Input a file name:deenaamazon.csv
# monthly summary:  Order Date
# 2017-01     13.38
# 2018-09     41.73
# 2018-10    231.92
# 2018-11     27.68
# 2018-12    690.01
# 2019-01    116.42
# 2019-02     90.50
# 2019-03     56.60
# 2019-04    183.01
# 2019-08    197.58
# 2019-09    281.65
# 2019-10      9.87
# 2019-11     45.46
# 2020-01    194.34
# 2020-02    105.85
# 2020-04     56.99
# 2020-09     15.08
# 2020-10     31.86
# 2020-12     15.19
# 2021-01     45.62
# 2021-03     41.36
# 2021-04     24.34
# 2021-05     13.31
# 2021-06     68.43
# 2021-10     62.49
# 2022-01    101.66
# Freq: M, Name: Total Charged, dtype: float64
# median:  15.92
# mean:  27.349801980198034
# median:  15.92
# max:  314.5
# min:  4.23
# std:  48.120113154068925
# sum:  2762.3300000000004
# ...

# %%
#Child Inheritance
class Graphs(Amazon):
    pass

    import pandas as pd
    def bar(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()

        df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
        df.head()
        import matplotlib.pyplot as plt
        df.plot.bar(x='Order Date', y='Tax Charged', rot=90, figsize=(20,10))
        plt.title("Tax Overtime")

        df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
        df.head()
        import matplotlib.pyplot as plt
        df.plot.bar(x='Order Date', y='Subtotal', rot=90, figsize=(20,10))
        plt.title("Subtotal Overtime")
    def pie(abc):
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
        df.head()
        df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
        df.head()
        import matplotlib.pyplot as plt
        Total=df["Subtotal"].sum()
        Tax=df["Tax Charged"].sum()
        cost = {'Subtotal':Total, 'Tax Charged':Tax}
        plt.pie(cost.values(), labels=cost.keys())
        plt.title("Tax to Subtotal Spending Proportion")
    def multi(abc):   
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
        df.head()
        df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
        df.head()
        import numpy as np
        import matplotlib.pyplot as plt

        x=np.array(df["Order Date"])
        y=np.array(df["Tax Charged"])
        x2=np.array(df["Order Date"])
        y2=np.array(df["Subtotal"])

        plt.subplot(1,1,1)
        plt.plot(x,y,x2,y2)

        plt.title("Multiple Lines Subplot")
    def multi(abc): 
        df = pd.read_csv('deenaamazon.csv')
        df=df.fillna(0)
        df.head()
        df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
        df.head()
        df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
        df.head()
        sale=df.groupby(pd.PeriodIndex(df["Order Date"],freq='M'))["Total Charged"].sum()
        import matplotlib.pyplot as plt
        df.plot(kind='line',x='Order Date',y='Total Charged');
        df.plot(kind='line',x='Order Date',y='Subtotal')
        plt.show()
        
x=Graphs(total)
x.bar()
x.pie()
x.multi()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_46565/2884928170.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_46565/2884928170.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
# ...

# %%
def main():
    input_readable = False
    while True:
        try: 
            f = input("Input a file name:")
            fp = open(f, "r")
            while fp:
                return fp
            #error statement if file cannot be found
        except FileNotFoundError:
            print("Something went wrong when opening this file. Try Again.")
        else:
            input_readable = True
    if __name__=='main':
        main()
